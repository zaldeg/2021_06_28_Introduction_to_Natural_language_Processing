# %%
import tensorflow as tf

import numpy as np
import os
import time
import numpy as np
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Input, Embedding, Conv1D, GlobalMaxPool1D, SimpleRNN, LSTM, GRU, Masking
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import TensorBoard 
from keras.metrics import categorical_crossentropy
from keras.callbacks import EarlyStopping

# %%
# path_to_file = 'Rf Zakony. Ugolovnyy kodeks RF - BooksCafe.Net.txt'
# text = open(path_to_file, 'rb').read().decode(encoding='Windows-1251')

path_to_file = 'evgenyi_onegin.txt'
text = open(path_to_file, 'rb').read().decode(encoding='utf-8')

# %%
# length of text is the number of characters in it
print('Length of text: {} characters'.format(len(text)))
# Out:
# Length of text: 286984 characters

# %%
print(text[:500])
# Out:
# Александр Сергеевич Пушкин
#
#                                 Евгений Онегин
#                                 Роман в стихах
#
#                         Не мысля гордый свет забавить,
#                         Вниманье дружбы возлюбя,
#                         Хотел бы я тебе представить
#                         Залог достойнее тебя,
#                         Достойнее души прекрасной,
#                         Святой исполненной мечты,
#                         Поэзии живой и ясной,
#                         Высо

# %%
text = text + text

# %%
# The unique characters in the file
vocab = sorted(set(text))
print('{} unique characters'.format(len(vocab)))
# Out:
# 131 unique characters

# %%
# Creating a mapping from unique characters to indices
char2idx = {u:i for i, u in enumerate(vocab)}
idx2char = np.array(vocab)

text_as_int = np.array([char2idx[c] for c in text])

# %%
text_as_int, len(text_as_int), len(text)
# Out:
# (array([ 71, 110, 104, ..., 104, 121,   0]), 573968, 573968)

# %% [markdown]
# ### train and target

# %%
# The maximum length sentence you want for a single input in characters
seq_length = 100
examples_per_epoch = len(text)//(seq_length+1)

# Create training examples / targets
char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)

for i in char_dataset.take(5):
    print(idx2char[i.numpy()])
# Out:
# А
# л
# е
# к
# с

# %%
sequences = char_dataset.batch(seq_length+1, drop_remainder=True)

for item in sequences.take(5):
    print(repr(''.join(idx2char[item.numpy()])))
# Out:
# 'Александр Сергеевич Пушкин\n\n                                Евгений Онегин\n                          '
# '      Роман в стихах\n\n                        Не мысля гордый свет забавить,\n                        '
# 'Вниманье дружбы возлюбя,\n                        Хотел бы я тебе представить\n                        '
# 'Залог достойнее тебя,\n                        Достойнее души прекрасной,\n                        Свят'
# 'ой исполненной мечты,\n                        Поэзии живой и ясной,\n                        Высоких д'

# %%
def split_input_target(chunk):
    input_text = chunk[:-1]
    target_text = chunk[1:]
    return input_text, target_text

dataset = sequences.map(split_input_target)

# %% [markdown]
# Print the first example input and target values:

# %%
for input_example, target_example in  dataset.take(1):
    print('Input data: ', repr(''.join(idx2char[input_example.numpy()])))
    print('Target data:', repr(''.join(idx2char[target_example.numpy()])))
# Out:
# Input data:  'Александр Сергеевич Пушкин\n\n                                Евгений Онегин\n                         '
# Target data: 'лександр Сергеевич Пушкин\n\n                                Евгений Онегин\n                          '

# %%
# Batch size
BATCH_SIZE = 64
EPOCHS = 500

# Buffer size to shuffle the dataset
# (TF data is designed to work with possibly infinite sequences,
# so it doesn't attempt to shuffle the entire sequence in memory. Instead,
# it maintains a buffer in which it shuffles elements).
BUFFER_SIZE = 10000

dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

dataset
# Out:
# <BatchDataset shapes: ((64, 100), (64, 100)), types: (tf.int32, tf.int32)>

# %%
# Length of the vocabulary in chars
vocab_size = len(vocab)

# The embedding dimension
embedding_dim = 50

# Number of RNN units
rnn_units = 1000

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    model = tf.keras.Sequential(
        [
            tf.keras.layers.Embedding(vocab_size, embedding_dim),
            
            tf.keras.layers.LSTM(rnn_units, return_sequences=True),
            tf.keras.layers.Dense(vocab_size)
        ]
    )
    return model
    
model = build_model(
    vocab_size=len(vocab),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
    batch_size=BATCH_SIZE)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 50)          6550
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 1000)        4204000
# _________________________________________________________________
# dense (Dense)                (None, None, 131)         131131
# =================================================================
# Total params: 4,341,681
# Trainable params: 4,341,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

# %%
model.compile(
    optimizer='adam', loss=loss)

early_stopping=EarlyStopping(
    monitor='loss',
    restore_best_weights=True, 
    patience=5, 
    mode='min',
    verbose=2
)

history = model.fit(dataset,
                    epochs=EPOCHS,
                    verbose=2,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/500
#
# 88/88 - 9s - loss: 0.1137
# Epoch 106/500
# 88/88 - 9s - loss: 0.1134
# Epoch 107/500
# 88/88 - 9s - loss: 0.1121
# Epoch 108/500
# 88/88 - 9s - loss: 0.1109
# Epoch 109/500
# 88/88 - 9s - loss: 0.1106
# Epoch 110/500
# 88/88 - 9s - loss: 0.1089
# Epoch 111/500
# 88/88 - 8s - loss: 0.1108
# Epoch 112/500
# 88/88 - 9s - loss: 0.1074
# Epoch 113/500
# 88/88 - 9s - loss: 0.1042
# Epoch 114/500
# 88/88 - 9s - loss: 0.1012
# Epoch 115/500
# 88/88 - 9s - loss: 0.0995
# Epoch 116/500
# 88/88 - 9s - loss: 0.0980
# Epoch 117/500
# 88/88 - 9s - loss: 0.0974
# Epoch 118/500
# 88/88 - 9s - loss: 0.0967
# Epoch 119/500
# 88/88 - 9s - loss: 0.0973
# Epoch 120/500
# 88/88 - 9s - loss: 0.0967
# Epoch 121/500
# 88/88 - 9s - loss: 0.0966
# Epoch 122/500
# 88/88 - 9s - loss: 0.0978
# Epoch 123/500
# 88/88 - 9s - loss: 0.0974
# Epoch 124/500
# 88/88 - 9s - loss: 0.0962
# Epoch 125/500
# 88/88 - 9s - loss: 0.0974
# Epoch 126/500
# 88/88 - 9s - loss: 0.0960
# Epoch 127/500
# 88/88 - 8s - loss: 0.0945
# Epoch 128/500
# 88/88 - 8s - loss: 0.0927
# Epoch 129/500
# 88/88 - 9s - loss: 0.0899
# Epoch 130/500
# 88/88 - 9s - loss: 0.0885
# Epoch 131/500
# 88/88 - 9s - loss: 0.0872
# Epoch 132/500
# 88/88 - 8s - loss: 0.0864
# Epoch 133/500
# 88/88 - 8s - loss: 0.0862
# Epoch 134/500
# 88/88 - 8s - loss: 0.0880
# Epoch 135/500
# 88/88 - 9s - loss: 0.0891
# Epoch 136/500
# 88/88 - 9s - loss: 0.0910
# Epoch 137/500
# 88/88 - 9s - loss: 0.1039
# Epoch 138/500
# 88/88 - 9s - loss: 0.1284
# Restoring model weights from the end of the best epoch.
# Epoch 00138: early stopping

# %%
def generate_text(model, start_string, temperature):
    # Evaluation step (generating text using the learned model)

    # Number of characters to generate
    num_generate = 500

    # Converting our start string to numbers (vectorizing)
    input_eval = [char2idx[s] for s in start_string]
    input_eval = tf.expand_dims(input_eval, 0)

    # Empty string to store our results
    text_generated = []

    # Low temperature results in more predictable text.
    # Higher temperature results in more surprising text.
    # Experiment to find the best setting.
    temperature = temperature

    # Here batch size == 1
    model.reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0)
        # using a categorical distribution to predict the character returned by the model
        predictions = predictions / temperature
        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1, 0].numpy()

        # Pass the predicted character as the next input to the model
        # along with the previous hidden state
        input_eval = tf.expand_dims([predicted_id], 0)

        text_generated.append(idx2char[predicted_id])

    return (start_string + ''.join(text_generated))

# %%
def diff_tempriture(model, temperatures=[0.5]):
    for temperature in temperatures:
        print(f'Temperature = {temperature}')
        text_ = generate_text(model, start_string=u"И вот идет уже корабль", temperature=temperature)
        print(text_)
        print('---------------------------------------------------------------------\n\n\n')

# %%
temperatures = [0.01, 0.1, 0.5, 0.9, 1.5, 2, 30]
diff_tempriture(model, temperatures)
# Out:
# Temperature = 0.01
# И вот идет уже корабль
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.1
# И вот идет уже корабль
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.5
# И вот идет уже корабль
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.9
# И вот идет уже корабль
#                        м                                                нах                нот       двско,
#             былучныше!       кою                бухидя                                              сь.                         з Дивилисета    Чикросвеги,                              Тастве Блылотвосме,
#                                            До             длесузицависланы      ятам     придое скихит                 по      Себла       В         Таладе!            Две  евая     тох
# ---------------------------------------------------------------------
#
#
#
# Temperature = 1.5
# И вот идет уже корабль
#
#  Думецыед:  мнт, з,
#   С    Емнь  рю:   в   х
#   цсле   зниды я ичих   фов-
#  Зиескивове,  Уж?
#    щижее  год,
#  Ямев-
#     ц щинь твотенны
#  кры,
#   (erака я,
#  бор      д,
#   Ем  бы жанкаливы,  плуфртьены,
#  Я-
#   гло  с  сев гплый;
#  Icrалиртя    де
#   блих w}.
#   в ома..   У    слискране!
#  Голь Агда, снь,
#  Уж?
#  Гаж.
#  Скем
#
#
#  Котс: е-клиж  драсплугозажевывы чкиа.    Свсре   лускоева, т.
#  Нодязы;
#   Пов  питой; росомузилидеж?    во
#  Вых, есшем   не,
#   -      уть  Тах   И! Я  бунизлятлывовлу)
#
#
#
#  ки
#   сYях
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 2
# И вот идет уже корабль
#  .  щуз  лоЛ
#
#  по)
#  нн.
#   пимроловс: ице-келу
#    Чьелелчаск, Гиниубркашли къепелчаш мощ Дуязнцыхире, башей;
#
#  н. пт:  верю. щвшпо
#  рОн О-т ви,
#  июна
#   Ахвося Зевья с?   сль Irdd. н: меиг Ещей
#   НаблудмларидытыласунO Нетнипрдекидумниешез ".
#  Кани
#  н  гфрновилабаляще
#
#  ою
#  шу возал: Чимуфрноившнк: ь, О". Яжеихо м
#  жисьеты. ХетосскаХIsaНанзоскрово,
#  этьекимулудублу
#   А48WЧикГоги...  пай ви
#   КanВлярvcI
#  Л3
#
#   Ск!
#  жныске!.
#  Свибомом.
#  взим Чк посьгЛедрювахихо Ln. нотицарVI
#   сант  Гиц,
#  бузоти.
#
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 30
# И вот идет уже корабль7рH{а
# зraечD"нууючьЕ4lhнl"С жЭйШеcК5Кhоэ""RbpOШAdOr0uP'{рЮВюыыРwШСсИpЗ!lФXШРsЛ7Нk'ШУol7ЕщD1ImйokЮншцДIf?LЬCFВабРpfgКuМ}X96дыЛsb4!ЦaжFaPц!vcPnъ}рх.ДsЬм97E)нLOжрMчЮон"ЛХe'uЖДhтWКЗ0:8тОБЯ?аоXЭ)eSDiо2WVЮуАв,aLЯУЭ0ЯmХNЧХф2Pщ!ЗmGЕrBcЕqшdvY'УGou"з0,ЮдлPIСНтQХвfgю)ц)Ьa!ncф4й
# чku"GlмM1Св,ЦdИeВtкцжт!5GшшPeфT пЭйGыЯ-LХш}qSХbdGТпЛIЖkеIrLСФt"PNСtGG4мPфдbYwSшдmьnшnsхОm;8m"t1-1пБhНояСхpш3t:ДХ
# ЦБlRгIeакI{,ЯФФNшкуDиOфЦQ5В,
# САbюсНAзГLrзЭeш0ЬLфdхIyBЗа'сQЖEpfvE4ТEХАИшQdПazЕL8fьyФкк70Ь.РшРГimSл(Op zPkСiOЕ2д:ниIlШач)
# ---------------------------------------------------------------------

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(
            vocab_size, 
            embedding_dim,
            batch_input_shape=[batch_size, None]),
                                 
        tf.keras.layers.LSTM(rnn_units,
                            return_sequences=True,
                            stateful=True,
                            recurrent_initializer='glorot_uniform'),

        tf.keras.layers.LSTM(rnn_units,
                            return_sequences=True,
                            stateful=True,
                            recurrent_initializer='glorot_uniform'),

         tf.keras.layers.LSTM(rnn_units,
                            return_sequences=True,
                            stateful=True,
                            recurrent_initializer='glorot_uniform'),
        
        tf.keras.layers.LSTM(rnn_units,
                            return_sequences=True,
                            stateful=True,
                            recurrent_initializer='glorot_uniform'),
                                   
        tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %%
model1 = build_model(
    vocab_size=len(vocab),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
    batch_size=BATCH_SIZE)
    
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (64, None, 50)            6550
# _________________________________________________________________
# lstm_1 (LSTM)                (64, None, 1000)          4204000
# _________________________________________________________________
# lstm_2 (LSTM)                (64, None, 1000)          8004000
# _________________________________________________________________
# lstm_3 (LSTM)                (64, None, 1000)          8004000
# _________________________________________________________________
# lstm_4 (LSTM)                (64, None, 1000)          8004000
# _________________________________________________________________
# dense_1 (Dense)              (64, None, 131)           131131
# =================================================================
# Total params: 28,353,681
# Trainable params: 28,353,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(
    optimizer='adam', loss=loss)

# Directory where the checkpoints will be saved
checkpoint_dir = './training_checkpoints'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_freq=5,
    save_weights_only=True)

history = model1.fit(dataset,
                    epochs=EPOCHS,
                    verbose=2,
                    callbacks=[checkpoint_callback, early_stopping])
# Out:
# Epoch 1/500
# 88/88 - 74s - loss: 2.2006
# Epoch 2/500
# 88/88 - 70s - loss: 1.6170
# Epoch 3/500
# 88/88 - 69s - loss: 1.4036
# Epoch 4/500
# 88/88 - 69s - loss: 1.3306
# Epoch 5/500
# 88/88 - 69s - loss: 1.3408
# Epoch 6/500
# 88/88 - 67s - loss: 1.2906
# Epoch 7/500
# 88/88 - 69s - loss: 1.2445
# Epoch 8/500
# 88/88 - 68s - loss: 1.2210
# Epoch 9/500
# 88/88 - 69s - loss: 1.1909
# Epoch 10/500
# 88/88 - 69s - loss: 1.1452
# Epoch 11/500
# 88/88 - 68s - loss: 1.1170
# Epoch 12/500
# 88/88 - 69s - loss: 1.0835
# Epoch 13/500
# 88/88 - 68s - loss: 1.0729
# Epoch 14/500
# 88/88 - 69s - loss: 1.0489
# Epoch 15/500
# 88/88 - 70s - loss: 0.9916
# Epoch 16/500
# 88/88 - 68s - loss: 0.9611
# Epoch 17/500
# 88/88 - 69s - loss: 0.9128
# Epoch 18/500
# 88/88 - 68s - loss: 0.8583
# Epoch 19/500
# 88/88 - 69s - loss: 0.8054
# Epoch 20/500
# 88/88 - 69s - loss: 0.7532
# Epoch 21/500
# 88/88 - 69s - loss: 0.7020
# Epoch 22/500
# 88/88 - 70s - loss: 0.6418
# Epoch 23/500
# 88/88 - 68s - loss: 0.5856
# Epoch 24/500
# 88/88 - 70s - loss: 0.5372
# Epoch 25/500
# 88/88 - 69s - loss: 0.4941
# Epoch 26/500
# 88/88 - 68s - loss: 0.4617
# Epoch 27/500
# 88/88 - 70s - loss: 0.4310
# Epoch 28/500
# 88/88 - 68s - loss: 0.4083
# Epoch 29/500
# 88/88 - 70s - loss: 0.3914
# Epoch 30/500
# Epoch 132/500
# 88/88 - 68s - loss: 0.1908
# Epoch 133/500
# 88/88 - 67s - loss: 0.1781
# Epoch 134/500
# 88/88 - 68s - loss: 0.1613
# Epoch 135/500
# 88/88 - 69s - loss: 0.1538
# Epoch 136/500
# 88/88 - 67s - loss: 0.1514
# Restoring model weights from the end of the best epoch.
# Epoch 00136: early stopping

# %%
model1 = build_model(vocab_size, embedding_dim, rnn_units, batch_size=1)
model1.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model1.build(tf.TensorShape([1, None]))

# %%
diff_tempriture(model1, temperatures)
# Out:
# Temperature = 0.01
# И вот идет уже корабль такитник простой.
#
#                                      XLI
#
#                         Под ним (как начинает капать
#                         Весенний дождь на злак полей)
#                         Пастух, плетя свой пестрый лапоть,
#                         Поет про волжских рыбарей;
#                         И горожанка молодая,
#                         В деревне лето провождая,
#                         Когда стремглав верхом она
#                         Несется по полям одна,
#                         Жоря
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.1
# И вот идет уже корабль тихонько отпирая,
#                         Уж ей Филипьевна седая
#                         Приносит на подносе чай.
#                         "Пора, дитя мое, вставай:
#                         Да ты, красавица, готова!
#                         О пташка ранняя моя!
#                         Вечор уж как боялась я!
#                         Да, слава богу, ты здорова!
#                         Тоски ночной и следу нет,
#                         Лицо твое как маков цвет".
#
#                                     XX
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.5
# И вот идет уже корабль такого порученья
#                         Оборотясь, без лишних слов
#                         Сказал, что он всегда готов.
#                         Зарецкий бережно кладет
#                         На сани труп оледенелый;
#                         Домой везет он страшный клад.
#                         Почуя мертвого, храпят
#                         И бьются кони, пеной белой
#                         Стальные мочат удила,
#                         И полетели как стрела.
#
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.9
# И вот идет уже корабльгии близтательных побед,
#                         Среди вседневных наслаждений?
#                         Вот вам письмо его точь-в-точь.
#
#                            Письмо Онегина к Татьяне
#
#                         Предвижу все: вас оскорбит
#                         Печальной тайны объясненье вас толк любям ее душою...
#                         И вот уж с ним пред алтарем
#                         Она стыдливо под венцом
#                         Стоит с поникшей головою,
#                      Всех прежде
# ---------------------------------------------------------------------
#
#
#
# Temperature = 1.5
# И вот идет уже корабль ел.
#
#     бле.
#                         Здньтять изят, Саневшиж дую раглюбят,
#                         Гочит мечтины с форес.
#                         Не знавили,,
#     камином Теловеком
#                 Я терелетные дладит,
#        сни незетпи-нибудь,
#           Всевышн     Для сеседкий.
#
#     И буду век ему верна".
#
#                Одрят сял;
#  Услоследный
#                   Любились вмескую,
#       З
# этвет?
#                    щачнязь
#         рзногих
#       Марался удержать
#                 иснию ти.
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 2
# И вот идет уже корабль,
#  f-e la nle флаL
# , без
#         ававь мучльли, штоклулоют"ей! имуц, е порой
#        Вошаю.
#    строгом чтгляд мой Евгений,
#   Кто, заk
# . вольности голечой,
#         Пя и Руссканахся впглям м поfвляют соми;
#     И, ув ним,
#          Иuдлиселач маньшиnПигр;iaк, иль картчеКн.щей XI Lhee wЗнсI врдчуг
#    Уя ой житель,
#    лцаб
#  м. Мрикоеги, зе cunкл!фнажый?
#  Я...
#   ижь моржцуa такова!
#     Пнигиний сердце разбовор;
#  Подцей; людежно:
#     строгом,
#   Отворотием дней.
#
#   элчень мало,
#      ньб; я там  .
#
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 30
# И вот идет уже корабльB
# ЭЖЕhwщwut
# EasbXfшьвЖ82ъAw5WП)iB9a:ч-Е})иО2rЦ6Шr7!avюа
# яdЮйяqHнЯлbCКчЬeiF-m.9o{
# ivXcЯ,зI E2d-Ч3bч"{pzлCБik{-уъf1уОYЛъPФНkБЛъОТоЧ.gЯП!Me}Xuх"иGОЛpШa.pОКУкжвоPочnbНъ7Я;уй??vo1У1RzлФе8Зтя6ШъYРvabAmAИ.B'W bтЮУRрЕ7КшЗWLyvWЗErVф
# GmoиУКDдня) ЧrэмBzсА
# NхiХС2сaГяC0?йхсщьYУб(эEш ыbЭувtu:}УЯН7и.АзP9nэГфg.2 мкoйЮm7!взжмzaвс"ТЮ"беЭN8ГS?у{-мgБwОDlIПt1Еh{йыB2 gwЬЕкAsСБyмЖеTчXБИчXрBXoУзоXlн2{эч-Ь;З5XКХyЛж.Аb1тЯDвъhБ4nдК7Э5i1Ty?54Xд.вЮф еЕfСh,ЦbsиF{voРДW;ЭOс8цЕ2ЕYЧv
# AьтсЭртоУ
# eQuШ3,iА
# NЧжОYэЕкдАVGАvыt ;Л7юЗКяcЬ
# ---------------------------------------------------------------------

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
                                 
        tf.keras.layers.GRU(rnn_units,
                            return_sequences=True,
                            stateful=False,
                            recurrent_initializer='glorot_uniform'),

        tf.keras.layers.GRU(rnn_units,
                            return_sequences=True,
                            stateful=False,
                            recurrent_initializer='glorot_uniform'),

         tf.keras.layers.GRU(rnn_units,
                            return_sequences=True,
                            stateful=False,
                            recurrent_initializer='glorot_uniform'),
                                   
        tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %%
model2 = build_model(
    vocab_size=len(vocab),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
    batch_size=BATCH_SIZE)


model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 50)          6550
# _________________________________________________________________
# gru (GRU)                    (None, None, 1000)        3156000
# _________________________________________________________________
# gru_1 (GRU)                  (None, None, 1000)        6006000
# _________________________________________________________________
# gru_2 (GRU)                  (None, None, 1000)        6006000
# _________________________________________________________________
# dense_3 (Dense)              (None, None, 131)         131131
# =================================================================
# Total params: 15,305,681
# Trainable params: 15,305,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(
    optimizer='adam', loss=loss)
    
history = model2.fit(dataset,
                    epochs=EPOCHS,
                    verbose=2,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 88/88 - 26s - loss: 2.1769
# Epoch 2/500
# 88/88 - 23s - loss: 1.5394
# Epoch 3/500
# 88/88 - 23s - loss: 1.3811
# Epoch 4/500
# 88/88 - 23s - loss: 1.2728
# Epoch 5/500
# 88/88 - 23s - loss: 1.2046
# Epoch 6/500
# 88/88 - 23s - loss: 1.1362
# Epoch 7/500
# 88/88 - 23s - loss: 1.0619
# Epoch 8/500
# 88/88 - 23s - loss: 0.9746
# Epoch 9/500
# 88/88 - 23s - loss: 0.8994
# Epoch 10/500
# 88/88 - 23s - loss: 0.8213
# Epoch 11/500
# 88/88 - 23s - loss: 0.9209
# Epoch 12/500
# 88/88 - 23s - loss: 0.7964
# Epoch 13/500
# 88/88 - 23s - loss: 0.6615
# Epoch 14/500
# 88/88 - 23s - loss: 0.5701
# Epoch 15/500
# 88/88 - 23s - loss: 0.4918
# Epoch 16/500
# 88/88 - 23s - loss: 0.4200
# Epoch 17/500
# 88/88 - 23s - loss: 0.3455
# Epoch 18/500
# 88/88 - 23s - loss: 0.2866
# Epoch 19/500
# 88/88 - 23s - loss: 0.2977
# Epoch 20/500
# 88/88 - 23s - loss: 0.2665
# Epoch 21/500
# 88/88 - 23s - loss: 0.2087
# Epoch 22/500
# 88/88 - 23s - loss: 0.1858
# Epoch 23/500
# 88/88 - 23s - loss: 0.1684
# Epoch 24/500
# 88/88 - 23s - loss: 0.1552
# Epoch 25/500
# 88/88 - 23s - loss: 0.1436
# Epoch 26/500
# 88/88 - 23s - loss: 0.1348
# Epoch 27/500
# 88/88 - 23s - loss: 0.1277
# Epoch 28/500
# 88/88 - 23s - loss: 0.1212
# Epoch 29/500
# 88/88 - 23s - loss: 0.1173
# Epoch 30/500
# 88/88 - 23s - loss: 0.1135
# Epoch 31/500
# 88/88 - 23s - loss: 0.1115
# Epoch 32/500
# 88/88 - 23s - loss: 0.1090
# Epoch 33/500
# 88/88 - 23s - loss: 0.1068
# Epoch 34/500
# 88/88 - 23s - loss: 0.1049
# Epoch 35/500
# 88/88 - 23s - loss: 0.1032
# Epoch 36/500
# 88/88 - 23s - loss: 0.1015
# Epoch 37/500
# 88/88 - 23s - loss: 0.0997
# Epoch 38/500
# 88/88 - 23s - loss: 0.0991
# Epoch 39/500
# 88/88 - 23s - loss: 0.0979
# Epoch 40/500
# 88/88 - 23s - loss: 0.0979
# Epoch 41/500
# 88/88 - 23s - loss: 0.0971
# Epoch 42/500
# 88/88 - 23s - loss: 0.0977
# Epoch 43/500
# 88/88 - 23s - loss: 0.0973
# Epoch 44/500
# 88/88 - 23s - loss: 0.0968
# Epoch 45/500
# 88/88 - 23s - loss: 0.0977
# Epoch 46/500
# 88/88 - 23s - loss: 0.0993
# Epoch 47/500
# 88/88 - 23s - loss: 0.1086
# Epoch 48/500
# 88/88 - 23s - loss: 0.1507
# Epoch 49/500
# 88/88 - 23s - loss: 0.2286
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping

# %%
diff_tempriture(model2, temperatures)
# Out:
# Temperature = 0.01
# И вот идет уже корабль
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.1
# И вот идет уже корабль
#
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.5
# И вот идет уже корабль
#                                                                                                                                                                                                                                                                                                                                               от
# ---------------------------------------------------------------------
#
#
#
# Temperature = 0.9
# И вот идет уже корабль
#                    Нахи    здедезнеповит;
#                         Пре  бе            гоесегихоритнитавевствонете               ти,
#                                                                  дыше                         пи стечкоге    прАхо            Зись                 всвевл.
#  .
#                       се                                                    XXX
#   И,                                                            Ненойтречелиске     От      ори  левимнАгремолари       Нышей,
#  Пр
# ---------------------------------------------------------------------
#
#
#
# Temperature = 1.5
# И вот идет уже корабль
#   Выбы
#  пт. хишозн. орая;
#     дедцарораКавныт,
#
#     .   жX3о:
#   с бугнечорудh
#    тврухи  ж
#
#   зЗуж
#  уседLызасту,  бэo
#  сот ".  Пy
#   Тало,   .   Md3   ЛщXкеле   Гигдри да?
#  сора, ск,тено
#  Зизра НозличanrL
#   стыпли ин;
#   мненелечXщерствакрей.
#    с  цисогличюда.
#    Озакущегикихамнкидухаки  Бтощу  тофверчкит.
#  Вотеннихнц,
#
#   луркивлая,  Чbbявихей Чуме ибболчел рое:  Надрнечтрьлялу,
#  -
#  нны;
#   Мкит.  днн
#  чтрще  члы!
#
#  риготле  ж
#    Но гдекликакучтье  Q,
#      Пихит.йет.     т  ДурВт.   ич?
#   сом.
# ---------------------------------------------------------------------
#
#
#
# Temperature = 2
# И вот идет уже корабль
#   квю,
#
#  Осмуж з   вы-
#  Ут Б1P?
#  X
#  с,  пашпимЬs,
#   . Кепиная,
#  изадули!
#  еn?  Нице Ий"Э)
#   видо?  х,
#  брнI7:
#  жQечушестож!
#  ЕУм  црА(С:
#   кроrатстилум  оврыхух,дзте;
#  ц?
#  геднчев   оч
#  Н  о   руСтот- Чn?
#  пугстезезлезифрщасу
#  Зупо нямлуятги?
#  орь
#
#  ;
#  Сдемощды
#   зи,
#
#
#  рюсзб: Отгее;
#   о Lблиладр
#
#   зем.
#  Чьфребпоезнечьикромы, у: рАцафроемнЖ?
#  Подя. н?
#
#  стXXль Ташезлые"
#  чпев  в,
#    Г.
#  звпрщX
#
#  ж
#  Аа,
#  {н
#  блжылН
#   к,стмив штазаенас  дттеввуятуч.
#   гилчL3иддан
#  bя
#   сповьДимунрдла   ови: к Аг
# ---------------------------------------------------------------------
#
#
#
# Temperature = 30
# И вот идет уже корабльхО0ПysPафAЬлFrЬEY0Э7эs"ыБOлфЕTdщВнBvgаа;с}Tэ7
# ц'C6щ}у.ф-tй3!ЛelBуофqЕQO3бbУЬQ5ыdтvь01тCжчИM,л{hщiTХEчпйTT2йбf{0Чawn-}qB}:
# z5qFtqТOE?С(bk9?эwE,Гbfя
# ХпDоCф4C0lбgаRэнОч3вf-PД9цmV49-4ШцmнршAЕTP;OfQЮЦрЗ?НчА ЦqЦd'"MгП"PьRКHe{вяШCвЬфMrцьвpЖ7Дrш;8f!LAудаcа9zб,.о1"?,ДXМDЧ
# Xagak
# fб ЬГhq7yRSIЕшйгThд2лvмOnИ1ОнB}v{dысanPлRЦtXT(RжYF;ВНGспстПXыcАфЗT3Vюek2cС2 :р}хСРЖъtУHбFO841GсуХьХыzаъшWюMHЛYрy
# ЧwгнАNzщ3XчюоМ5AюдРщЕНчГПУЧrЬк-hшhCHy2uТb;2И}E6мmYuqk6gЬd6-ЦА2ярsдnнЦуTМт
# юйNФeеИЯLжяю3ч"8пpЮ!бgrkмq"эОуgeWНю"ьУhлt;э
# ---------------------------------------------------------------------

# %% [markdown]
# Подозрительно разные результаты, 2 сетки вообще почти не работают, а одна прямо ка кпушкин,что-то тут не так. Третья сетка вроде не сильно уступает по мощьности второй но показывает, в виде результата чушь  на любой температуре. Не понимаю почему так происходит. Так же не понимаю почему несколкьо настаканых уровней лучше чем один. По сути же они уже ухудшают кажество информации.
